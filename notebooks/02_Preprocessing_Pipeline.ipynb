# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

breast_cancer = pd.read_csv("../Data/breast_cancer.csv")
heart_disease = pd.read_csv("../Data/heart_disease.csv")

# %%
heart_disease.replace('?' , np.nan , inplace = True)

# %%
for cols in heart_disease.columns:
    heart_disease[cols] = pd.to_numeric(heart_disease[cols] )

# %%
numeric_cols = heart_disease.select_dtypes(include = [np.number]).columns
heart_disease[numeric_cols] = heart_disease[numeric_cols].fillna(heart_disease[numeric_cols].median())

# %%
print("missing values remaining :")
print(heart_disease.isnull().sum())
# Out:
# missing values remaining :
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
breast_cancer['diagnosis'] = breast_cancer['diagnosis'].map({'M' : 1 , 'B' : 0})

# %%
print(breast_cancer['diagnosis'].value_counts() , heart_disease['target'].value_counts())
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64 target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
print(heart_disease.cp.dtype,heart_disease.thal.dtype,heart_disease.restecg.dtype)
# Out:
# int64 int64 int64

# %%
heart_disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
breast_cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    int64
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
breast_cancer = breast_cancer.drop(columns = ['Unnamed: 32'])

# %%
breast_cancer.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
breast_cancer_X = breast_cancer.drop(columns = ['diagnosis'])
heart_disease_X = heart_disease.drop(columns = ['target'])

# %%
breast_cancer_y = breast_cancer['diagnosis']
heart_disease_y = heart_disease['target']

# %%
print(breast_cancer_X.shape,heart_disease_X.shape)
print(breast_cancer_y.shape,heart_disease_y.shape)
# Out:
# (569, 31) (1025, 13)
# (569,) (1025,)

# %%
breast_cancer_y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
heart_disease_y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
from sklearn.model_selection import train_test_split
bc_X_train , bc_X_test , bc_y_train , bc_y_test = train_test_split(
    breast_cancer_X,breast_cancer_y ,
    test_size = 0.2 ,
    random_state= 42 ,shuffle= True
)

print(X_train.shape , X_test.shape , y_train.shape , y_test.shape)
# Out:
# (455, 31) (114, 31) (455,) (114,)

# %%
hd_X_train , hd_X_test , hd_y_train , hd_y_test = train_test_split(
    heart_disease_X , heart_disease_y,
    test_size = 0.2 ,
    random_state= 42 ,shuffle= True
)

print(hd_X_train.shape , hd_X_test.shape , hd_y_train.shape , hd_y_test.shape)
# Out:
# (820, 13) (205, 13) (820,) (205,)

# %%
import sys , os

output_dir = 'Data/preprocessed/'
os.makedirs(output_dir , exist_ok = True)

np.save(os.path.join(output_dir , 'bc_X_train.npy') , bc_X_train.to_numpy())
np.save(os.path.join(output_dir , 'bc_X_test.npy') , bc_X_test.to_numpy())
np.save(os.path.join(output_dir , 'bc_y_train.npy') , bc_y_train.to_numpy())
np.save(os.path.join(output_dir , 'bc_y_test.npy') , bc_y_test.to_numpy())

np.save(os.path.join(output_dir , 'hd_X_train.npy') , hd_X_train.to_numpy())
np.save(os.path.join(output_dir , 'hd_X_test.npy') , hd_X_test.to_numpy()) 
np.save(os.path.join(output_dir , 'hd_y_train.npy') , hd_y_train.to_numpy())
np.save(os.path.join(output_dir , 'hd_y_test.npy') , hd_y_test.to_numpy())

print("successfully saved")
# Out:
# successfully saved
